# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipePenaSales/case_picpay/blob/main/Case_PICPAY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case de dados PICPAY Banking PJ

# %% [markdown]
# ## Importando as bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## Importando os dados e criando variaveis importantes do código

# %%
df = pd.read_excel("/content/transactions_v5.xlsx", sheet_name="transactions")
#df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   client_id                249 non-null    int64
#  1   month_date_transaction   249 non-null    int64
#  2   registration_month_date  249 non-null    int64
#  3   product_type             249 non-null    object
#  4   direction                249 non-null    object
#  5   client_action            249 non-null    bool
#  6   is_approved              249 non-null    bool
#  7   total_value              249 non-null    int64
# dtypes: bool(2), int64(4), object(2)
# memory usage: 12.3+ KB

# %%
# 1) Ver todas as colunas disponíveis
df.columns.tolist()
# Out:
# ['client_id',
#  'month_date_transaction',
#  'registration_month_date',
#  'product_type',
#  'direction',
#  'client_action',
#  'is_approved',
#  'total_value']

# %%
# 2) Dar uma olhada rápida em alguns valores (ajuda a identificar produto/status/direção)
df.head(3)
# Out:
#    client_id  month_date_transaction  registration_month_date   product_type  \
# 0          6                       1                        1  CARTAO_DEBITO
# 1          3                       1                        1  CARTAO_DEBITO
# 2         10                       1                        1  CARTAO_DEBITO
#
#   direction  client_action  is_approved  total_value
# 0       OUT           True         True          428
# 1       OUT           True         True          429
# 2       OUT           True         True          281

# %%
df.to_csv("transactions_v5.csv", index=False)
